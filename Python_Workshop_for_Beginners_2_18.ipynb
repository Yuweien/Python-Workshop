# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuweien/Python-Workshop/blob/main/Python_Workshop_for_Beginners_2_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ‧₊˚✩ ₊˚💻⊹♡ ✨ Python for Absolute Beginners ✨ ‧₊˚✩ ₊˚💻⊹♡
# ## Session 1: Understanding Python Logic

# %% [markdown]
# # 👋 Welcome! 📄➡️📂 Please make a copy of this notebook:
#
# 🔗 The link is in the Zoom chat.
#
# 🚀 Click **File → Save a copy in Drive** (or **Copy to Drive**) to get your own editable version.

# %% [markdown]
# ## Preparation before we start:
# 1. 📄 Open **your own copy** of this Google Colab notebook.
# 2. ✨ We’ll use the built-in AI assistant in Colab today.
#    You can open it by clicking the blue star icon at the bottom of the Colab window.
#
# 3. For now, just watch the demonstration.
#    After each step, I’ll pause and give you time to try it yourself if you’d like.

# %% [markdown]
# ### 1. How this notebook works

# %%
# This is a code cell, and this line is a comment.
print("Hi, I'm a code cell.")  # comment can be added after code, and be ignored when runing the code.
# Out:
# Hi, I'm a code cell.

# %% [markdown]
# This is a text cell. People also call me “markdown” cell.
# <!-- Student Ask AI：what is markdown? -->

# %% [markdown]
# ### 2. What is Python and how code runs

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ### 3. Variables and basic data types

# %%
# examples

# %% [markdown]
# ### 4. Data structures: lists and dictionaries

# %% [markdown]
# ### 5. Reading an existing script
